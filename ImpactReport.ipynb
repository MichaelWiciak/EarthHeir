# %%
# load impactReportData.csv
import pandas as pd
# Read the CSV file
data = pd.read_csv('impactReportData.csv', header=None)
# Convert the data to a list of lists
data_list = data.values.tolist()
# Print the data
for row in data_list:
    print(row)

years = list(range(2013, 2025))
# Out:
# [42485.55, 55964.76, 13002.1, 89878.43, 86979.38, 86043.27, 82680.36, 197594.62, 59740.81, 69177.54, 55655.6, 457138.34]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(years, data_array[0], color='blue')
plt.title('How we progress over the years in terms of amount spent on artisans')
plt.xlabel('Years')
plt.ylabel('Amount Spent on Artisans')
plt.xticks(years, rotation=45)
plt.grid(axis='y')
plt.gca().set_yticklabels([])  # Hide y-axis numbers
plt.tight_layout()
plt.savefig('amount_spent_on_artisans.png')
plt.show()

# %%
# 
accumulatedTotalArtisans = [115,		189,		267,		320,		436,		436,		501,		541,		608,		611,		624,	636]
plt.figure(figsize=(10, 6))
plt.bar(years, accumulatedTotalArtisans, color='green')
plt.title('Accumulated Total Artisans Over the Years')
plt.xlabel('Years')
plt.ylabel('Total Artisans')
plt.xticks(years, rotation=45)
plt.grid(axis='y')
# plt.gca().set_yticklabels([])  # Hide y-axis numbers
plt.tight_layout()
plt.savefig('accumulated_total_artisans.png')
plt.show()

# %%
# Make training hours cumulative
cumulative_training_hours = [sum(trainingHours[:i+1]) for i in range(len(trainingHours))]
plt.figure(figsize=(10, 6))
plt.bar(years, cumulative_training_hours, color='orange')
plt.title('Cumulative Training Hours Over the Years')
plt.xlabel('Years')
plt.ylabel('Training Hours')
plt.xticks(years, rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.savefig('cumulative_training_hours.png')
plt.show()

# %%
# Pie chart for cost breakdown
labels = ['Artisan Labour & Material', 'Logistics & Shipping', 'Operating Costs',
          'Packaging', 'Marketing', 'Retail Sales Commission', 'Product Development', 'Margin']
sizes = [31, 6, 15, 4, 3, 35, 1, 5]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6', '#c2f0c2', '#ffb366']
explode = (0.1, 0, 0, 0, 0, 0, 0, 0)  # explode the first slice
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Cost Breakdown of Nelly Bags')
plt.tight_layout()
plt.savefig('cost_breakdown_nelly_bags.png')
plt.show()
